# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2 + 3

# %%
3 + 4

# %%
## ESC+ B To Creat new Kernel Below
## ESC+ A To Creat new Kernel Below

# %%
3 + 4   # ctrl + enter only gives the output (its only execute there )
        # shift + enter its give output with new kernel (Current cell is executed and next cell is selected)
        # alt + enter its give output and creat new Kernel

# %%
10 + 10

# %%
print(sunil)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-25864fa2c38c> in <module>
# ----> 1 print(sunil)
#
# NameError: name 'sunil' is not defined

# %%
print("suni")  # correct way to print
# Out:
# suni

# %%
Print("sunil") # here P is in Capital Latter so output is not coming
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-caa6e5bdece2> in <module>
# ----> 1 Print("sunil")
#
# NameError: name 'Print' is not defined

# %%
a = 3   # 3 and 5 in green color means its 3 is fuction its alredy been defined.
b = 5
a + b
# Out:
# 8

# %% [markdown]
# # Advanced Certification in AIML
#
#
#
#
#
#
#
#
# ## A program by Datafolkz
#
# ### Introduction to Python
#
# # Intro to Jupyter Notebook
#
# - SHIFT + ENTER for EXECuting the CELL using Jupyter notebook
# Shortcut in both modes:
# - Shift + Enter run the Current cell, select below
# - Ctrl + Enter run selected cell
# - Alt + Enter run the currect cell, insert below
# - Ctrl + S save and checkpoint
# - Alt + Enter run the current cell ,insert below
# - Esc + m for code to markdown
# - Esc + y for markdown to code

# %%
#### monty python's flying circus,its a Unoited Kingdom Show.
#### Guido van Rossum
firstnumber = 4
firstnumber
# Out:
# 4

# %%
1stnumber = 5  # here we cannote start with numeric number (there fore its giving syntaxerror) variable canote be started with n
# Out:
#   File "<ipython-input-20-dd93b17027e7>", line 1
#     1stnumber = 5
#      ^
# SyntaxError: invalid syntax

# %%
import(keyword.python)
# Out:
#   File "<ipython-input-24-36df29c69f28>", line 1
#     import(keyword.python)
#           ^
# SyntaxError: invalid syntax

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ![image.png](attachment:image.png)
